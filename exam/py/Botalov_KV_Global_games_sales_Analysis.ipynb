# %%
# Импорт необходимых библиотек
import os.path                      # os - для работы с файлами операционной системы
import pandas as pd                 # pandas - для работы с табличными данными

# %%
# Путь к исходному CSV-файлу
file_path = '../src/vgchartz-2024.csv'

# Проверка существования файла по заданному пути
os.path.exists(file_path)
# Out:
# True

# %%
# Загрузка CSV файла в DataFrame Pandas
try:
    df = pd.read_csv(file_path)
    display('Файл загружен!')
except FileNotFoundError:
    display('Файл отсутствует!')
# Out:
# 'Файл загружен!'

# %%
# Вывод типа переменной df - исследуемого набора данных
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Выводим десять случайных строк набора данных
df.sample(10)
# Out:
#                                                      img  \
# 7547           /games/boxart/full_2614660PALFrontccc.jpg
# 58018      /games/boxart/full_8230385AmericaFrontccc.jpg
# 35765      /games/boxart/full_7020299AmericaFrontccc.jpg
# 6531       /games/boxart/full_8514191AmericaFrontccc.jpg
# 1991       /games/boxart/full_7838058AmericaFrontccc.jpg
# 22387  /games/boxart/full_spider-man-lethal-foes_10Ja...
# 31287         /games/boxart/full_535004JapanFrontccc.jpg
# 5097       /games/boxart/full_7120054AmericaFrontccc.jpg
# 4222                        /games/boxart/6879397ccc.jpg
# 40871      /games/boxart/full_4315198AmericaFrontccc.jpg
#
#                                title console         genre  \
# 7547        Rabbids Party Collection     Wii          Misc
# 58018                  Madden NFL 07    X360        Sports
# 35765    Magic: The Gathering Online      PC          Misc
# 6531       Mortal Kombat: Armageddon     Wii      Fighting
# 1991                NCAA Football 08     PS2        Sports
# 22387        Spider-Man: Lethal Foes    SNES        Action
# 31287  Mad Stalker: Full Metal Force      PS      Fighting
# 5097                            Fuel    X360        Racing
# 4222       Naruto: Path of the Ninja      DS  Role-Playing
# 40871           Gex: Enter the Gecko      GB      Platform
#
#                   publisher                     developer  critic_score  \
# 7547                Ubisoft           Ubisoft Montpellier           NaN
# 58018             EA Sports                    EA Tiburon           8.2
# 35765  Wizards of the Coast  Leaping Lizard Software Inc.           NaN
# 6531           Midway Games             JGI Entertainment           6.8
# 1991        Electronic Arts                    EA Tiburon           NaN
# 22387                 Epoch                        Agenda           NaN
# 31287           Family Soft                   Family Soft           NaN
# 5097            Codemasters                  Asobo Studio           6.6
# 4222           D3 Publisher                          TOSE           NaN
# 40871   Crave Entertainment   David A. Palmer Productions           NaN
#
#        total_sales  na_sales  jp_sales  pal_sales  other_sales release_date  \
# 7547          0.18       NaN       NaN       0.16         0.02   2010-08-27
# 58018          NaN       NaN       NaN        NaN          NaN   2006-08-22
# 35765          NaN       NaN       NaN        NaN          NaN   2002-06-14
# 6531          0.23      0.19       NaN       0.02         0.02   2007-05-29
# 1991          0.79      0.65       NaN       0.03         0.11   2007-07-17
# 22387          NaN       NaN       NaN        NaN          NaN   1995-03-17
# 31287          NaN       NaN       NaN        NaN          NaN   1997-07-03
# 5097          0.31      0.09       0.0       0.18         0.04   2009-06-02
# 4222          0.40      0.37       NaN        NaN         0.03   2007-10-23
# 40871          NaN       NaN       NaN        NaN          NaN   1998-12-01
#
#       last_update
# 7547          NaN
# 58018         NaN
# 35765         NaN
# 6531          NaN
# 1991          NaN
# 22387         NaN
# 31287         NaN
# 5097   2020-08-05
# 4222          NaN
# 40871         NaN

# %%
# Получение размера набора данных (количество строк и столбцов)
display(df.shape)

# Получение списка названий столбцов
display(df.columns)
# Out:
# (64016, 14)
# Index(['img', 'title', 'console', 'genre', 'publisher', 'developer',
#        'critic_score', 'total_sales', 'na_sales', 'jp_sales', 'pal_sales',
#        'other_sales', 'release_date', 'last_update'],
#       dtype='object')

# %%
# Отображение набора данных в сокращенном виде
display(df)
# Out:
#                                                  img  \
# 0      /games/boxart/full_6510540AmericaFrontccc.jpg
# 1      /games/boxart/full_5563178AmericaFrontccc.jpg
# 2                        /games/boxart/827563ccc.jpg
# 3      /games/boxart/full_9218923AmericaFrontccc.jpg
# 4      /games/boxart/full_4990510AmericaFrontccc.jpg
# ...                                              ...
# 64011  /games/boxart/full_2779838AmericaFrontccc.jpg
# 64012  /games/boxart/full_8031506AmericaFrontccc.jpg
# 64013  /games/boxart/full_6553045AmericaFrontccc.jpg
# 64014    /games/boxart/full_6012940JapanFrontccc.png
# 64015                      /games/boxart/default.jpg
#
#                                   title console         genre  \
# 0                    Grand Theft Auto V     PS3        Action
# 1                    Grand Theft Auto V     PS4        Action
# 2           Grand Theft Auto: Vice City     PS2        Action
# 3                    Grand Theft Auto V    X360        Action
# 4             Call of Duty: Black Ops 3     PS4       Shooter
# ...                                 ...     ...           ...
# 64011             XBlaze Lost: Memories      PC  Visual Novel
# 64012                      Yoru, Tomosu     PS4  Visual Novel
# 64013                      Yoru, Tomosu      NS  Visual Novel
# 64014   Yunohana SpRING! ~Mellow Times~      NS  Visual Novel
# 64015  Yurukill: The Calumniation Games     PS4  Visual Novel
#
#                   publisher             developer  critic_score  total_sales  \
# 0            Rockstar Games        Rockstar North           9.4        20.32
# 1            Rockstar Games        Rockstar North           9.7        19.39
# 2            Rockstar Games        Rockstar North           9.6        16.15
# 3            Rockstar Games        Rockstar North           NaN        15.86
# 4                Activision              Treyarch           8.1        15.09
# ...                     ...                   ...           ...          ...
# 64011           Aksys Games      Arc System Works           NaN          NaN
# 64012  Nippon Ichi Software  Nippon Ichi Software           NaN          NaN
# 64013  Nippon Ichi Software  Nippon Ichi Software           NaN          NaN
# 64014          Idea Factory               Otomate           NaN          NaN
# 64015               Unknown            G.rev Ltd.           NaN          NaN
#
#        na_sales  jp_sales  pal_sales  other_sales release_date last_update
# 0          6.37      0.99       9.85         3.12   2013-09-17         NaN
# 1          6.06      0.60       9.71         3.02   2014-11-18  2018-01-03
# 2          8.41      0.47       5.49         1.78   2002-10-28         NaN
# 3          9.06      0.06       5.33         1.42   2013-09-17         NaN
# 4          6.18      0.41       6.05         2.44   2015-11-06  2018-01-14
# ...         ...       ...        ...          ...          ...         ...
# 64011       NaN       NaN        NaN          NaN   2016-08-11  2019-01-28
# 64012       NaN       NaN        NaN          NaN   2020-07-30  2020-05-09
# 64013       NaN       NaN        NaN          NaN   2020-07-30  2020-05-09
# 64014       NaN       NaN        NaN          NaN   2019-02-28  2019-02-24
# 64015       NaN       NaN        NaN          NaN          NaN  2023-09-29
#
# [64016 rows x 14 columns]

# %%
# Вывод сводной информации о наборе данных
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64016 entries, 0 to 64015
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   img           64016 non-null  object
#  1   title         64016 non-null  object
#  2   console       64016 non-null  object
#  3   genre         64016 non-null  object
#  4   publisher     64016 non-null  object
#  5   developer     63999 non-null  object
#  6   critic_score  6678 non-null   float64
#  7   total_sales   18922 non-null  float64
#  8   na_sales      12637 non-null  float64
#  9   jp_sales      6726 non-null   float64
#  10  pal_sales     12824 non-null  float64
#  11  other_sales   15128 non-null  float64
#  12  release_date  56965 non-null  object
#  13  last_update   17879 non-null  object
# dtypes: float64(6), object(8)
# memory usage: 6.8+ MB

# %%
# Подсчет количества null-значений в наборе данных
df.isnull().sum()
# Out:
# img                 0
# title               0
# console             0
# genre               0
# publisher           0
# developer          17
# critic_score    57338
# total_sales     45094
# na_sales        51379
# jp_sales        57290
# pal_sales       51192
# other_sales     48888
# release_date     7051
# last_update     46137
# dtype: int64

# %%
# Определение минимумов и максимумов для числовых значений
df.describe()
# Out:
#        critic_score   total_sales      na_sales     jp_sales     pal_sales  \
# count   6678.000000  18922.000000  12637.000000  6726.000000  12824.000000
# mean       7.220440      0.349113      0.264740     0.102281      0.149472
# std        1.457066      0.807462      0.494787     0.168811      0.392653
# min        1.000000      0.000000      0.000000     0.000000      0.000000
# 25%        6.400000      0.030000      0.050000     0.020000      0.010000
# 50%        7.500000      0.120000      0.120000     0.040000      0.040000
# 75%        8.300000      0.340000      0.280000     0.120000      0.140000
# max       10.000000     20.320000      9.760000     2.130000      9.850000
#
#         other_sales
# count  15128.000000
# mean       0.043041
# std        0.126643
# min        0.000000
# 25%        0.000000
# 50%        0.010000
# 75%        0.030000
# max        3.120000

# %%
# Импорт необходимых библиотек для переноса данных
from sqlalchemy import create_engine    # Набор инструментов для работы с SQL из Python
import psycopg2     # Коннектор к СУБД PostgreSQL из Python

# %%
# Пример: 'postgresql://username:password@localhost:5432/your_database'
engine = create_engine('postgresql://postgres:changeme@localhost:5432/innopolis')

df.to_sql(
    name="innopolis", # имя таблицы
    con=engine,  # движок
    if_exists="append", # если таблица уже существует, добавляем
    index=False # без индекса
)
# Out:
# 16
